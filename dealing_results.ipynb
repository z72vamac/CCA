# %%
import pandas as pd

import numpy as np

# %%
matriz_resultados = pd.read_csv('matriz_resultados2.csv', header=None).iloc[:, 1:]

matriz_resultados
# Out:
#                        1                     2                     3  \
# 0   6                     lasso                 2
# 1   6                     lasso                 2
# 2   6                     lasso                 2
# 3   6                     lasso                 2
# 4   6                     lasso                 2
# 5   6                     lasso                 3
# 6   6                     lasso                 3
# 7   6                     lasso                 3
# 8   6                     lasso                 3
# 9   6                     lasso                 3
# 10  7                     lasso                 2
# 11  7                     lasso                 2
# 12  7                     lasso                 2
# 13  NA                    NA                    NA
# 14  7                     lasso                 2
# 15  7                     lasso                 3
# 16  7                     lasso                 3
# ...

# %%
pd.read_csv("results/results05.csv")
# Out:
#      Unnamed: 0  dataset        method  k1  k2  ObjVal_Train  ObjVal_Test  \
# 0             0        0    greedy_CCA   3   3      0.813503     0.822773
# 1             1        0    greedy_CCA   3   3      0.824060     0.808059
# 2             2        0    greedy_CCA   3   3      0.838847     0.769787
# 3             3        0    greedy_CCA   3   3      0.827361     0.797434
# 4             4        0    greedy_CCA   3   3      0.833117     0.827711
# ..          ...      ...           ...  ..  ..           ...          ...
# 623         129        5  combined_CCA  10  10      0.868310     0.866567
# 624         130        5  combined_CCA  10  10      0.867350     0.866025
# 625         131        5  combined_CCA  10  10      0.868486     0.868189
# 626         132        5  combined_CCA  10  10      0.869394     0.864931
# 627         133        5  combined_CCA  10  10      0.866720     0.867807
#
#      Time_Elapsed  N_Iter
# 0        0.504050      -1
# ...

# %%
pd.read_csv("results/results_new.csv")
# Out:
#      Unnamed: 0  dataset  scaling               method  k1  k2  ObjVal_Train  \
# 0             0        6    False           greedy_CCA   2   2      0.813352
# 1             1        6    False           greedy_CCA   2   2      0.853882
# 2             2        6    False           greedy_CCA   2   2      0.826046
# 3             3        6    False           greedy_CCA   2   2      0.818599
# 4             4        6    False           greedy_CCA   2   2      0.796717
# ..          ...      ...      ...                  ...  ..  ..           ...
# 738         738        5    False       multistart_CCA   3   3      1.907939
# 739         739        5    False  benders_CCA_without   3   3      0.799897
# 740         740        5    False  benders_CCA_without   3   3      0.777616
# 741         741        5    False  benders_CCA_without   3   3      0.706883
# 742         742        5    False  benders_CCA_without   3   3      0.779566
#
#      ObjVal_Test  Time_Elapsed  N_Iter
# ...

# %%
pd.read_csv("")
